# %%
def suma(a=0, b=0): #Parametros nombrados
    print(a+b)

# %%
suma()
suma(2,)
suma(b=5)
# Out:
# 0
# 2
# 5

# %% [markdown]
# ascii en C
#
# printf("%d \n", 'a');
#
#
#
# cuando le pones el id obtiene el id del valor, no de la variable
#
# difrencias de parametro y argumento
#
# def <function_name>([<parameters>])
#
# parametros cuando defines la funcion
#
# y argumentos cuando le mandas a llamar
#
#
# append añade datos a una lista
